# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.pie([1])
plt.show()

# %%
Batches = ["PYTHON","R","ML","AI","DS"]
stu1_marks = [30,20,35,40,45]

#stu2_marks = [34,25,34,44,48]
#stu3_marks = [33,28,39,49,41]


plt.pie(stu1_marks)
plt.show()

# %%
Batches = ["PYTHON","R","ML","AI","DS"]

stu1_marks = [30,20,35,40,45]

textprops = { 'fontsize': 15 }

plt.pie(stu1_marks , labels = Batches ,  textprops = textprops )

plt.show()

# %%
plt.figure(figsize=(18,10))

Batches = ["PYTHON","R","ML","AI","DS"]

stu1_marks = [30,20,35,40,45]

plt.pie(stu1_marks , labels = Batches ,   shadow= True ,     labeldistance=1.4)

plt.show()

# %%
plt.figure(figsize=(18,10))

Batches = ["PYTHON","R","ML","AI","DS"]

stu1_marks = [30,20,35,40,45]


explode=[0,0,0.2,0,0]

plt.pie(stu1_marks , labels = Batches , shadow= True    ,  explode=explode)

plt.show()

# %%
plt.figure(figsize=(18,10))

Batches = ["PYTHON","R","ML","AI","DS"]

stu1_marks = [30,20,35,40,45]


explode=[0,0,0.2,0,0.5]

colors = ["y","b","y","b","y"]

plt.pie(stu1_marks , labels = Batches , shadow= True ,  explode=explode ,  colors = colors )

plt.show()

# %%
plt.figure(figsize=(10,5))

Batches = ["PYTHON","R","ML","AI","DS"]

stu1_marks = [30,20,35,40,45]

plt.pie(stu1_marks , labels = Batches, shadow= True ,     autopct="% 0.1f %% " )

plt.show()

# %%
plt.figure(figsize=(10,5))

Batches = ["PYTHON","R","ML","AI","DS"]

stu1_marks = [30,20,35,40,45]

plt.pie(stu1_marks , labels = Batches ,      autopct="% 0.1f %% " ,   pctdistance=0.9  )
 
plt.show()

# %%
plt.figure(figsize=(10,5))

Batches = ["PYTHON","R","ML","AI","DS"]

stu1_marks = [30,20,35,40,45]

plt.pie(stu1_marks , labels = Batches ,     startangle= 90  )

plt.show()

# %%
plt.figure(figsize=(10,5))

Batches = ["PYTHON","R","ML","AI","DS"]

stu1_marks = [30,20,35,40,45]

plt.pie(stu1_marks , labels = Batches ,       startangle= 270 ,   radius=1.4 )

plt.show()

# %%
Batches = ["PYTHON","R","ML","AI","DS"]

stu1_marks = [30,20,35,40,45]


wedgeprops = { "linewidth": 4 , "width": 1 , "edgecolor": "k"}



plt.pie(stu1_marks , labels = Batches ,       wedgeprops = wedgeprops )

plt.show()

# %%
Batches = ["PYTHON","R","ML","AI","DS"]

stu1_marks = [30,20,35,40,45]

explode=[0,0,0.2,0,0]

wedgeprops = { "linewidth": 4 , "width": 1 , "edgecolor": "k"}

plt.pie(stu1_marks , labels = Batches ,   wedgeprops = wedgeprops , explode=explode )

plt.show()

# %%
Batches = ["PYTHON","R","ML","AI","DS"]

stu1_marks = [30,20,35,40,45]

explode=[0,0,0.2,0,0]

wedgeprops = { "linewidth": 4 , "width": 1 , "edgecolor": "k"}

plt.pie(stu1_marks , labels = Batches ,   wedgeprops = wedgeprops , explode=explode )

plt.legend()

plt.show()
