# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.style

# %% [raw]
# What are the Differences Between Bar Chart and Histogram?
#
# --The bar graph is the graphical representation of categorical data.
#
# --A histogram is the graphical representation of quantitative data.
#   There is equal space between each pair of consecutive bars.

# %%
Batches = ["PYTHON","R","ML","AI","DS"]
stu1_marks = [30,20,35,40,45]
stu2_marks = [34,25,34,44,48]
stu3_marks = [33,28,39,49,41]

# %%
plt.bar(Batches,stu1_marks) #  width=0.8 is default here
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(Batches,stu1_marks,  width=0.5)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(Batches,stu1_marks,  width=0.5 , color = "r")
# Out:
# <BarContainer object of 5 artists>

# %%
#plt.barh( Batches,stu1_marks,  width=0.5 , color = "r")
# error : barh() got multiple values for argument 'width'

plt.barh( Batches,stu1_marks, color = "r")    # after removing *width
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar( Batches,stu1_marks, color = "y", align='edge')
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar( Batches,stu1_marks, color = "y", align='edge', edgecolor = 'm', linewidth = 5)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar( Batches,stu1_marks, color = "y",align='edge', edgecolor = 'm', linewidth = 5, alpha = 0.5) # alpha range = 0 to 1
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar( Batches,stu1_marks, color = "y",align='edge', edgecolor = 'm', linewidth = 5, alpha = 0.2) # alpha range = 0 to 1
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar( Batches,stu1_marks, color = "y",align='edge', edgecolor = 'm', linewidth = 5, alpha = 0.8) # alpha range = 0 to 1
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar( Batches,stu1_marks, color = "y",align='edge', edgecolor = 'm', linewidth = 5, alpha = 0.8, linestyle = "--")
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar( Batches,stu1_marks, color = "y",align='edge', edgecolor = 'm', linewidth = 5, alpha = 0.8, label ="stu1_marks")
plt.legend()

# %%
plt.bar( Batches,stu1_marks, color = "y",align='edge', edgecolor = 'm', linewidth = 5, alpha = 0.8,
        label ="stu1_marks",  visible = False)

plt.legend()

# %%
plt.figure( figsize = (15,5))

plt.bar( Batches,stu1_marks, color = "y",label ="stu1_marks")

plt.bar( Batches,stu2_marks, color = "b",label ="stu2_marks")


plt.legend()

# %%
plt.figure( figsize = (10,5))

Batches_index = np.arange(len(Batches))


width = 0.2

plt.bar( Batches_index  ,stu1_marks, color = "y",label ="stu1_marks")

plt.bar(Batches_index + width  ,stu2_marks, color = "b",label ="stu2_marks")


plt.legend()

# %%
#plt.figure( figsize = (5,5))

Batches_index = np.arange(len(Batches))

width = 0.2

plt.bar( Batches_index  ,stu1_marks, color = "y",label ="stu1_marks")

plt.bar(Batches_index + width  ,stu2_marks, color = "b",label ="stu2_marks")

plt.xticks ( Batches_index + width , Batches )


plt.legend()

# %%
plt.figure( figsize = (16,9))

Batches_index = np.arange(len(Batches))

rwidth = 0.2

plt.bar( Batches_index  ,stu1_marks, color = "y",label ="stu1_marks")

plt.bar(Batches_index + width  ,stu2_marks, color = "m",label ="stu2_marks")


plt.xticks ( Batches_index + width , Batches , rotation = 25 )


plt.legend()

# %%
plt.figure( figsize = (16,9))

Batches_index = np.arange(len(Batches))

width = 0.2

plt.bar( Batches_index  ,stu1_marks,     width,    color = "y",label ="stu1_marks")

plt.bar(Batches_index + width  ,stu2_marks,     width,    color = "m",label ="stu2_marks")

plt.bar(Batches_index + width + width ,stu3_marks,    width,    color = "g",label ="stu3_marks")

#  after passing width inside command its take value

plt.xticks ( Batches_index + width , Batches , rotation = 25 )


plt.legend()

# %%
plt.figure( figsize = (16,9))

Batches_index = np.arange(len(Batches))

width = 0.2

plt.bar( Batches_index  ,stu1_marks,     width,    color = "y",label ="stu1_marks")

plt.bar(Batches_index + width  ,stu2_marks,     width,    color = "m",label ="stu2_marks")

plt.bar(Batches_index + width + width ,stu3_marks,    width,    color = "g",label ="stu3_marks")

#  after passing width inside command its take value

plt.xticks ( Batches_index + width , Batches , rotation = 25 )


plt.legend()


plt.title("Student Result", fontsize = 18)
plt.xlabel("Batches category", fontsize = 15)
plt.ylabel("Student marks", fontsize = 15)
# Out:
# Text(0, 0.5, 'Student marks')

# %%
plt.figure( figsize = (16,9))

Batches = ["PYTHON","R","ML","AI","DS"]
stu1_marks = [30,20,35,40,45]
stu2_marks = [34,25,34,44,48]
stu3_marks = [33,28,39,49,41]

Batches_index = np.arange(len(Batches))

width = 0.2

plt.barh( Batches_index  ,stu1_marks,     width,    color = "y",label ="stu1_marks")

plt.barh(Batches_index + width  ,stu2_marks,     width,    color = "m",label ="stu2_marks")

plt.barh(Batches_index + width + width ,stu3_marks,    width,    color = "g",label ="stu3_marks")

#  after passing width inside command its take value

plt.xticks ( Batches_index + width , Batches , rotation = 25 )


plt.legend()


plt.title("Student Result", fontsize = 18)
plt.xlabel("Batches category", fontsize = 15)
plt.ylabel("Student marks", fontsize = 15)
# Out:
# Text(0, 0.5, 'Student marks')
