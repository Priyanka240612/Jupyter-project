# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.style

# %%
plt.pie([20,30,40,10])
plt.savefig("pie_fig")
plt.show()

# %%
# savefig(fname, *, dpi='figure', format=None, metadata=None,
 #         bbox_inches=None, pad_inches=0.1,
  #        facecolor='auto', edgecolor='auto',
   #       backend=None, **kwargs
    #     )

# %%
plt.pie([20,30,40,10])
plt.savefig("pie_fig2" , dpi= 100 , facecolor= "b", edgecolor= "k" )
plt.show()

# %%
Batches = ["PYTHON","R","ML","AI","DS"]
stu1_marks = [30,20,35,40,45]
stu2_marks = [34,25,34,44,48]
stu3_marks = [33,28,39,49,41]
plt.bar( Batches,stu1_marks, color = "y", align='edge', edgecolor = 'm', linewidth = 5)

plt.savefig("C:\Bar_fig.png")
plt.show()
