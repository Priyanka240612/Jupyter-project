# %%
import pandas as pd

# %%
sr1 = pd.Series([221,222,223,224,225])
sr1
# Out:
# 0    221
# 1    222
# 2    223
# 3    224
# 4    225
# dtype: int64

# %%
sr2 = pd.Series([501,502,503,504,505])
sr2
# Out:
# 0    501
# 1    502
# 2    503
# 3    504
# 4    505
# dtype: int64

# %%
C1 = pd.concat([sr1,sr2])
C1
# Out:
# 0    221
# 1    222
# 2    223
# 3    224
# 4    225
# 0    501
# 1    502
# 2    503
# 3    504
# 4    505
# dtype: int64

# %%
C2 = pd.concat([sr1,sr2], axis = 0 )
C2
# Out:
# 0    221
# 1    222
# 2    223
# 3    224
# 4    225
# 0    501
# 1    502
# 2    503
# 3    504
# 4    505
# dtype: int64

# %%
C3 = pd.concat([sr1,sr2], axis = 1 )
C3
# Out:
#      0    1
# 0  221  501
# 1  222  502
# 2  223  503
# 3  224  504
# 4  225  505

# %%
sr3 = pd.Series([701,702,703,704,705,706,707])
sr3
# Out:
# 0    701
# 1    702
# 2    703
# 3    704
# 4    705
# 5    706
# 6    707
# dtype: int64

# %%
C4 = pd.concat([sr2,sr3]  )
C4
# Out:
# 0    501
# 1    502
# 2    503
# 3    504
# 4    505
# 0    701
# 1    702
# 2    703
# 3    704
# 4    705
# 5    706
# 6    707
# dtype: int64

# %%
C4a = pd.concat([sr2,sr3] , axis = 1  )
C4a
# Out:
#        0    1
# 0  501.0  701
# 1  502.0  702
# 2  503.0  703
# 3  504.0  704
# 4  505.0  705
# 5    NaN  706
# 6    NaN  707

# %%
df1 = pd.DataFrame({'ID':[101,102,103,104,105],'Class':[1,2,3,4,5],'Name':['A','B','C','D','E'] })
df1
# Out:
#     ID  Class Name
# 0  101      1    A
# 1  102      2    B
# 2  103      3    C
# 3  104      4    D
# 4  105      5    E

# %%
df2= pd.DataFrame({'ID':[106,107,108,109,1010],'Class':[6,7,8,9,10], 'Name':['F','G','H','I','J']})
df2
# Out:
#      ID  Class Name
# 0   106      6    F
# 1   107      7    G
# 2   108      8    H
# 3   109      9    I
# 4  1010     10    J

# %%
C5 = pd.concat([df1 , df2])
C5
# Out:
#      ID  Class Name
# 0   101      1    A
# 1   102      2    B
# 2   103      3    C
# 3   104      4    D
# 4   105      5    E
# 0   106      6    F
# 1   107      7    G
# 2   108      8    H
# 3   109      9    I
# 4  1010     10    J

# %%
C5a = pd.concat([ df2 , df1] )
C5a
# Out:
#      ID  Class Name
# 0   106      6    F
# 1   107      7    G
# 2   108      8    H
# 3   109      9    I
# 4  1010     10    J
# 0   101      1    A
# 1   102      2    B
# 2   103      3    C
# 3   104      4    D
# 4   105      5    E

# %%
C6 = pd.concat([df1, df2] ,axis= 1)
C6
# Out:
#     ID  Class Name    ID  Class Name
# 0  101      1    A   106      6    F
# 1  102      2    B   107      7    G
# 2  103      3    C   108      8    H
# 3  104      4    D   109      9    I
# 4  105      5    E  1010     10    J

# %%
C6a = pd.concat([df1, df2] ,axis= 1 , ignore_index = True)
C6a
# Out:
#      0  1  2     3   4  5
# 0  101  1  A   106   6  F
# 1  102  2  B   107   7  G
# 2  103  3  C   108   8  H
# 3  104  4  D   109   9  I
# 4  105  5  E  1010  10  J

# %%
C6aa = pd.concat([df1, df2] ,axis= 0 , ignore_index = True)
C6aa
# Out:
#      ID  Class Name
# 0   101      1    A
# 1   102      2    B
# 2   103      3    C
# 3   104      4    D
# 4   105      5    E
# 5   106      6    F
# 6   107      7    G
# 7   108      8    H
# 8   109      9    I
# 9  1010     10    J

# %%
C6b = pd.concat([df1, df2] ,axis= 0 , ignore_index = False)
C6b
# Out:
#      ID  Class Name
# 0   101      1    A
# 1   102      2    B
# 2   103      3    C
# 3   104      4    D
# 4   105      5    E
# 0   106      6    F
# 1   107      7    G
# 2   108      8    H
# 3   109      9    I
# 4  1010     10    J

# %%
C6bb = pd.concat([df1, df2] ,axis= 1 , ignore_index = False)
C6bb
# Out:
#     ID  Class Name    ID  Class Name
# 0  101      1    A   106      6    F
# 1  102      2    B   107      7    G
# 2  103      3    C   108      8    H
# 3  104      4    D   109      9    I
# 4  105      5    E  1010     10    J

# %%
df2
# Out:
#      ID  Class Name
# 0   106      6    F
# 1   107      7    G
# 2   108      8    H
# 3   109      9    I
# 4  1010     10    J

# %%
df3 = pd.DataFrame({'ID':[107,108,109],'Class':[7,8,9], 'Name':['G','H','I']})
df3
# Out:
#     ID  Class Name
# 0  107      7    G
# 1  108      8    H
# 2  109      9    I

# %%
C7 = pd.concat([df2,df3])
C7
# Out:
#      ID  Class Name
# 0   106      6    F
# 1   107      7    G
# 2   108      8    H
# 3   109      9    I
# 4  1010     10    J
# 0   107      7    G
# 1   108      8    H
# 2   109      9    I

# %%
C7a = pd.concat([df2,df3] , axis = 1)
C7a
# Out:
#      ID  Class Name     ID  Class Name
# 0   106      6    F  107.0    7.0    G
# 1   107      7    G  108.0    8.0    H
# 2   108      8    H  109.0    9.0    I
# 3   109      9    I    NaN    NaN  NaN
# 4  1010     10    J    NaN    NaN  NaN

# %%
C8 = pd.concat([df2,df3] , join = 'inner')
C8
# Out:
#      ID  Class Name
# 0   106      6    F
# 1   107      7    G
# 2   108      8    H
# 3   109      9    I
# 4  1010     10    J
# 0   107      7    G
# 1   108      8    H
# 2   109      9    I

# %%
C8a = pd.concat([df2,df3] ,axis = 1, join = 'inner')   # work only with AXIS
C8a
# Out:
#     ID  Class Name   ID  Class Name
# 0  106      6    F  107      7    G
# 1  107      7    G  108      8    H
# 2  108      8    H  109      9    I

# %%
C8b = pd.concat([df2,df3] , join = 'outer')
C8b
# Out:
#      ID  Class Name
# 0   106      6    F
# 1   107      7    G
# 2   108      8    H
# 3   109      9    I
# 4  1010     10    J
# 0   107      7    G
# 1   108      8    H
# 2   109      9    I

# %%
C8b = pd.concat([df2,df3] ,axis = 1, join = 'outer')    
C8b
# Out:
#      ID  Class Name     ID  Class Name
# 0   106      6    F  107.0    7.0    G
# 1   107      7    G  108.0    8.0    H
# 2   108      8    H  109.0    9.0    I
# 3   109      9    I    NaN    NaN  NaN
# 4  1010     10    J    NaN    NaN  NaN

# %%
df1
# Out:
#     ID  Class Name
# 0  101      1    A
# 1  102      2    B
# 2  103      3    C
# 3  104      4    D
# 4  105      5    E

# %%
df2
# Out:
#      ID  Class Name
# 0   106      6    F
# 1   107      7    G
# 2   108      8    H
# 3   109      9    I
# 4  1010     10    J

# %%
C9 = pd.concat([df1,df2] , keys = ['df1','df2'])    
C9
# Out:
#          ID  Class Name
# df1 0   101      1    A
#     1   102      2    B
#     2   103      3    C
#     3   104      4    D
#     4   105      5    E
# df2 0   106      6    F
#     1   107      7    G
#     2   108      8    H
#     3   109      9    I
#     4  1010     10    J

# %%
C9a = pd.concat([df1,df2] , keys = [ '1st','Second']) 
C9a
# Out:
#             ID  Class Name
# 1st    0   101      1    A
#        1   102      2    B
#        2   103      3    C
#        3   104      4    D
#        4   105      5    E
# Second 0   106      6    F
#        1   107      7    G
#        2   108      8    H
#        3   109      9    I
#        4  1010     10    J

# %%
C9a = pd.concat([df1,df2], axis= 1 , keys = [ '1st','Second']) 
C9a
# Out:
#    1st            Second
#     ID Class Name     ID Class Name
# 0  101     1    A    106     6    F
# 1  102     2    B    107     7    G
# 2  103     3    C    108     8    H
# 3  104     4    D    109     9    I
# 4  105     5    E   1010    10    J

# %%
df1
# Out:
#     ID  Class Name
# 0  101      1    A
# 1  102      2    B
# 2  103      3    C
# 3  104      4    D
# 4  105      5    E

# %%
df4 = pd.DataFrame({'Marks': [60,65,70,75,80]})
df4
# Out:
#    Marks
# 0     60
# 1     65
# 2     70
# 3     75
# 4     80

# %%
C10 = pd.concat([df1,df4])
C10
# Out:
#       ID  Class Name  Marks
# 0  101.0    1.0    A    NaN
# 1  102.0    2.0    B    NaN
# 2  103.0    3.0    C    NaN
# 3  104.0    4.0    D    NaN
# 4  105.0    5.0    E    NaN
# 0    NaN    NaN  NaN   60.0
# 1    NaN    NaN  NaN   65.0
# 2    NaN    NaN  NaN   70.0
# 3    NaN    NaN  NaN   75.0
# 4    NaN    NaN  NaN   80.0

# %%
C10a = pd.concat([df1,df4] , sort = False)
C10a
# Out:
#       ID  Class Name  Marks
# 0  101.0    1.0    A    NaN
# 1  102.0    2.0    B    NaN
# 2  103.0    3.0    C    NaN
# 3  104.0    4.0    D    NaN
# 4  105.0    5.0    E    NaN
# 0    NaN    NaN  NaN   60.0
# 1    NaN    NaN  NaN   65.0
# 2    NaN    NaN  NaN   70.0
# 3    NaN    NaN  NaN   75.0
# 4    NaN    NaN  NaN   80.0

# %%
C10aa = pd.concat([df1,df4] , sort = True )    # not in use
C10aa
# Out:
#    Class     ID  Marks Name
# 0    1.0  101.0    NaN    A
# 1    2.0  102.0    NaN    B
# 2    3.0  103.0    NaN    C
# 3    4.0  104.0    NaN    D
# 4    5.0  105.0    NaN    E
# 0    NaN    NaN   60.0  NaN
# 1    NaN    NaN   65.0  NaN
# 2    NaN    NaN   70.0  NaN
# 3    NaN    NaN   75.0  NaN
# 4    NaN    NaN   80.0  NaN
