# %% [markdown]
# # InterPolate()

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\Workspace\Pri\data science and ML practice\jupyter\students.csv', parse_dates=['Date'] )
df
# Out:
#          Date  Stu_ID    Class  Stdy_hrs  Slpng_hrs  present_per_no  \
# 0  2016-06-11     1.0   Health         2          9             1.0
# 1  2016-07-11     2.0   Health         6          8             2.0
# 2  2016-08-11     NaN   Health         3          8             3.0
# 3  2016-09-11     NaN    Sport         0         10             NaN
# 4  2016-10-11     5.0    Sport         4          7             NaN
# 5  2016-11-11     6.0    Sport        10          7             6.0
# 6         NaN     7.0      NaN         6          7             5.0
# 7         NaN     8.0    Dance         6          8             NaN
# 8         NaN     9.0  Singing         8          9             4.0
# 9  2016-15-11    10.0  Singing         6          9            10.0
#
#    Mob.Games_hrs Perctg  dumy
# 0            5.0     50   yes
# 1            0.0     80   yes
# 2            4.0     60    no
# 3            5.0     45    no
# 4            4.0     75   yes
# 5            NaN     96  yes
# ...

# %%
df.interpolate()      # fill all numeric value as per forward count BUT not change string value LIKE *class-nan
# Out:
#          Date  Stu_ID    Class  Stdy_hrs  Slpng_hrs  present_per_no  \
# 0  2016-06-11     1.0   Health         2          9             1.0
# 1  2016-07-11     2.0   Health         6          8             2.0
# 2  2016-08-11     3.0   Health         3          8             3.0
# 3  2016-09-11     4.0    Sport         0         10             4.0
# 4  2016-10-11     5.0    Sport         4          7             5.0
# 5  2016-11-11     6.0    Sport        10          7             6.0
# 6         NaN     7.0      NaN         6          7             5.0
# 7         NaN     8.0    Dance         6          8             4.5
# 8         NaN     9.0  Singing         8          9             4.0
# 9  2016-15-11    10.0  Singing         6          9            10.0
#
#    Mob.Games_hrs Perctg  dumy
# 0            5.0     50   yes
# 1            0.0     80   yes
# 2            4.0     60    no
# 3            5.0     45    no
# 4            4.0     75   yes
# 5           42.0     96  yes
# ...

# %%
itp1 = df.interpolate( method= 'linear')     # same as df.interpolate()
itp1
# Out:
#          Date  Stu_ID    Class  Stdy_hrs  Slpng_hrs  present_per_no  \
# 0  2016-06-11     1.0   Health         2          9             1.0
# 1  2016-07-11     2.0   Health         6          8             2.0
# 2  2016-08-11     3.0   Health         3          8             3.0
# 3  2016-09-11     4.0    Sport         0         10             4.0
# 4  2016-10-11     5.0    Sport         4          7             5.0
# 5  2016-11-11     6.0    Sport        10          7             6.0
# 6         NaN     7.0      NaN         6          7             5.0
# 7         NaN     8.0    Dance         6          8             4.5
# 8         NaN     9.0  Singing         8          9             4.0
# 9  2016-15-11    10.0  Singing         6          9            10.0
#
#    Mob.Games_hrs Perctg  dumy
# 0            5.0     50   yes
# 1            0.0     80   yes
# 2            4.0     60    no
# 3            5.0     45    no
# 4            4.0     75   yes
# 5           42.0     96  yes
# ...

# %%
itp2 = df.interpolate( limit= 1) # By setting limits its only change as per define limit value * please refer itp1 database
itp2                             # compaire itp1 and itp2 databases result
# Out:
#          Date  Stu_ID    Class  Stdy_hrs  Slpng_hrs  present_per_no  \
# 0  2016-06-11     1.0   Health         2          9             1.0
# 1  2016-07-11     2.0   Health         6          8             2.0
# 2  2016-08-11     3.0   Health         3          8             3.0
# 3  2016-09-11     NaN    Sport         0         10             4.0
# 4  2016-10-11     5.0    Sport         4          7             NaN
# 5  2016-11-11     6.0    Sport        10          7             6.0
# 6         NaN     7.0      NaN         6          7             5.0
# 7         NaN     8.0    Dance         6          8             4.5
# 8         NaN     9.0  Singing         8          9             4.0
# 9  2016-15-11    10.0  Singing         6          9            10.0
#
#    Mob.Games_hrs Perctg  dumy
# 0            5.0     50   yes
# 1            0.0     80   yes
# 2            4.0     60    no
# 3            5.0     45    no
# 4            4.0     75   yes
# 5           42.0     96  yes
# ...

# %%
df
# Out:
#          Date  Stu_ID    Class  Stdy_hrs  Slpng_hrs  present_per_no  \
# 0  2016-06-11     1.0   Health         2          9             1.0
# 1  2016-07-11     2.0   Health         6          8             2.0
# 2  2016-08-11     NaN   Health         3          8             3.0
# 3  2016-09-11     NaN    Sport         0         10             NaN
# 4  2016-10-11     5.0    Sport         4          7             NaN
# 5  2016-11-11     6.0    Sport        10          7             6.0
# 6         NaN     7.0      NaN         6          7             5.0
# 7         NaN     8.0    Dance         6          8             NaN
# 8         NaN     9.0  Singing         8          9             4.0
# 9  2016-15-11    10.0  Singing         6          9            10.0
#
#    Mob.Games_hrs Perctg  dumy
# 0            5.0     50   yes
# 1            0.0     80   yes
# 2            4.0     60    no
# 3            5.0     45    no
# 4            4.0     75   yes
# 5            NaN     96  yes
# ...

# %%
df.interpolate( limit_direction='Backward') # fill value as per backward value
# Out:
#          Date  Stu_ID    Class  Stdy_hrs  Slpng_hrs  present_per_no  \
# 0  2016-06-11     1.0   Health         2          9             1.0
# 1  2016-07-11     2.0   Health         6          8             2.0
# 2  2016-08-11     3.0   Health         3          8             3.0
# 3  2016-09-11     4.0    Sport         0         10             4.0
# 4  2016-10-11     5.0    Sport         4          7             5.0
# 5  2016-11-11     6.0    Sport        10          7             6.0
# 6         NaN     7.0      NaN         6          7             5.0
# 7         NaN     8.0    Dance         6          8             4.5
# 8         NaN     9.0  Singing         8          9             4.0
# 9  2016-15-11    10.0  Singing         6          9            10.0
#
#    Mob.Games_hrs Perctg  dumy
# 0            5.0     50   yes
# 1            0.0     80   yes
# 2            4.0     60    no
# 3            5.0     45    no
# 4            4.0     75   yes
# 5           42.0     96  yes
# ...

# %%
df.interpolate(limit = 1, limit_direction='Backward')
# Out:
#          Date  Stu_ID    Class  Stdy_hrs  Slpng_hrs  present_per_no  \
# 0  2016-06-11     1.0   Health         2          9             1.0
# 1  2016-07-11     2.0   Health         6          8             2.0
# 2  2016-08-11     NaN   Health         3          8             3.0
# 3  2016-09-11     4.0    Sport         0         10             NaN
# 4  2016-10-11     5.0    Sport         4          7             5.0
# 5  2016-11-11     6.0    Sport        10          7             6.0
# 6         NaN     7.0      NaN         6          7             5.0
# 7         NaN     8.0    Dance         6          8             4.5
# 8         NaN     9.0  Singing         8          9             4.0
# 9  2016-15-11    10.0  Singing         6          9            10.0
#
#    Mob.Games_hrs Perctg  dumy
# 0            5.0     50   yes
# 1            0.0     80   yes
# 2            4.0     60    no
# 3            5.0     45    no
# 4            4.0     75   yes
# 5           42.0     96  yes
# ...

# %%
df.interpolate( limit_direction='Forward')
# Out:
#          Date  Stu_ID    Class  Stdy_hrs  Slpng_hrs  present_per_no  \
# 0  2016-06-11     1.0   Health         2          9             1.0
# 1  2016-07-11     2.0   Health         6          8             2.0
# 2  2016-08-11     3.0   Health         3          8             3.0
# 3  2016-09-11     4.0    Sport         0         10             4.0
# 4  2016-10-11     5.0    Sport         4          7             5.0
# 5  2016-11-11     6.0    Sport        10          7             6.0
# 6         NaN     7.0      NaN         6          7             5.0
# 7         NaN     8.0    Dance         6          8             4.5
# 8         NaN     9.0  Singing         8          9             4.0
# 9  2016-15-11    10.0  Singing         6          9            10.0
#
#    Mob.Games_hrs Perctg  dumy
# 0            5.0     50   yes
# 1            0.0     80   yes
# 2            4.0     60    no
# 3            5.0     45    no
# 4            4.0     75   yes
# 5           42.0     96  yes
# ...

# %%
df.interpolate( limit_direction='Both')
# Out:
#          Date  Stu_ID    Class  Stdy_hrs  Slpng_hrs  present_per_no  \
# 0  2016-06-11     1.0   Health         2          9             1.0
# 1  2016-07-11     2.0   Health         6          8             2.0
# 2  2016-08-11     3.0   Health         3          8             3.0
# 3  2016-09-11     4.0    Sport         0         10             4.0
# 4  2016-10-11     5.0    Sport         4          7             5.0
# 5  2016-11-11     6.0    Sport        10          7             6.0
# 6         NaN     7.0      NaN         6          7             5.0
# 7         NaN     8.0    Dance         6          8             4.5
# 8         NaN     9.0  Singing         8          9             4.0
# 9  2016-15-11    10.0  Singing         6          9            10.0
#
#    Mob.Games_hrs Perctg  dumy
# 0            5.0     50   yes
# 1            0.0     80   yes
# 2            4.0     60    no
# 3            5.0     45    no
# 4            4.0     75   yes
# 5           42.0     96  yes
# ...

# %%
df.interpolate(inplace = False)
df
# Out:
#          Date  Stu_ID    Class  Stdy_hrs  Slpng_hrs  present_per_no  \
# 0  2016-06-11     1.0   Health         2          9             1.0
# 1  2016-07-11     2.0   Health         6          8             2.0
# 2  2016-08-11     NaN   Health         3          8             3.0
# 3  2016-09-11     NaN    Sport         0         10             NaN
# 4  2016-10-11     5.0    Sport         4          7             NaN
# 5  2016-11-11     6.0    Sport        10          7             6.0
# 6         NaN     7.0      NaN         6          7             5.0
# 7         NaN     8.0    Dance         6          8             NaN
# 8         NaN     9.0  Singing         8          9             4.0
# 9  2016-15-11    10.0  Singing         6          9            10.0
#
#    Mob.Games_hrs Perctg  dumy
# 0            5.0     50   yes
# 1            0.0     80   yes
# 2            4.0     60    no
# 3            5.0     45    no
# 4            4.0     75   yes
# 5            NaN     96  yes
# ...

# %%
df.interpolate(inplace = True)
df
# Out:
#          Date  Stu_ID    Class  Stdy_hrs  Slpng_hrs  present_per_no  \
# 0  2016-06-11     1.0   Health         2          9             1.0
# 1  2016-07-11     2.0   Health         6          8             2.0
# 2  2016-08-11     3.0   Health         3          8             3.0
# 3  2016-09-11     4.0    Sport         0         10             4.0
# 4  2016-10-11     5.0    Sport         4          7             5.0
# 5  2016-11-11     6.0    Sport        10          7             6.0
# 6         NaN     7.0      NaN         6          7             5.0
# 7         NaN     8.0    Dance         6          8             4.5
# 8         NaN     9.0  Singing         8          9             4.0
# 9  2016-15-11    10.0  Singing         6          9            10.0
#
#    Mob.Games_hrs Perctg  dumy
# 0            5.0     50   yes
# 1            0.0     80   yes
# 2            4.0     60    no
# 3            5.0     45    no
# 4            4.0     75   yes
# 5           42.0     96  yes
# ...

# %%
df
# Out:
#          Date  Stu_ID    Class  Stdy_hrs  Slpng_hrs  present_per_no  \
# 0  2016-06-11     1.0   Health         2          9             1.0
# 1  2016-07-11     2.0   Health         6          8             2.0
# 2  2016-08-11     3.0   Health         3          8             3.0
# 3  2016-09-11     4.0    Sport         0         10             4.0
# 4  2016-10-11     5.0    Sport         4          7             5.0
# 5  2016-11-11     6.0    Sport        10          7             6.0
# 6         NaN     7.0      NaN         6          7             5.0
# 7         NaN     8.0    Dance         6          8             4.5
# 8         NaN     9.0  Singing         8          9             4.0
# 9  2016-15-11    10.0  Singing         6          9            10.0
#
#    Mob.Games_hrs Perctg  dumy
# 0            5.0     50   yes
# 1            0.0     80   yes
# 2            4.0     60    no
# 3            5.0     45    no
# 4            4.0     75   yes
# 5           42.0     96  yes
# ...

# %%
type(df.Date[0])
# Out:
# str

# %%
df1 = pd.read_csv( 'C:\Workspace\Pri\data science and ML practice\jupyter\students.csv' )
df1.parse_dates= ['date']
df1
# Out:
# C:\Users\yada029\AppData\Local\Temp\ipykernel_13676\2756611273.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df1.parse_dates= ['date']
#          Date  Stu_ID    Class  Stdy_hrs  Slpng_hrs  present_per_no  \
# 0  2016-06-11     1.0   Health         2          9             1.0
# 1  2016-07-11     2.0   Health         6          8             2.0
# 2  2016-08-11     NaN   Health         3          8             3.0
# 3  2016-09-11     NaN    Sport         0         10             NaN
# 4  2016-10-11     5.0    Sport         4          7             NaN
# 5  2016-11-11     6.0    Sport        10          7             6.0
# 6         NaN     7.0      NaN         6          7             5.0
# 7         NaN     8.0    Dance         6          8             NaN
# 8         NaN     9.0  Singing         8          9             4.0
# ...

# %%
df1.columns
# Out:
# Index(['Date', 'Stu_ID', 'Class', 'Stdy_hrs', 'Slpng_hrs', 'present_per_no',
#        'Mob.Games_hrs', 'Perctg', 'dumy'],
#       dtype='object')

# %%
type(df1.Date[0])
# Out:
# str

# %%
df = pd.read_csv('C:\Workspace\Pri\data science and ML practice\jupyter\students.csv',parse_dates=['Date'] )
df
# Out:
#          Date  Stu_ID    Class  Stdy_hrs  Slpng_hrs  present_per_no  \
# 0  2016-06-11     1.0   Health         2          9             1.0
# 1  2016-07-11     2.0   Health         6          8             2.0
# 2  2016-08-11     NaN   Health         3          8             3.0
# 3  2016-09-11     NaN    Sport         0         10             NaN
# 4  2016-10-11     5.0    Sport         4          7             NaN
# 5  2016-11-11     6.0    Sport        10          7             6.0
# 6         NaN     7.0      NaN         6          7             5.0
# 7         NaN     8.0    Dance         6          8             NaN
# 8         NaN     9.0  Singing         8          9             4.0
# 9  2016-15-11    10.0  Singing         6          9            10.0
#
#    Mob.Games_hrs Perctg  dumy
# 0            5.0     50   yes
# 1            0.0     80   yes
# 2            4.0     60    no
# 3            5.0     45    no
# 4            4.0     75   yes
# 5            NaN     96  yes
# ...

# %%
# df.interpolate(method='time')
# ValueError: time-weighted interpolation only works on Series or DataFrames with a DatetimeIndex

# %%
#type(df['Date'])
type(df.Date[0])
# Out:
# str

# %%
df = pd.read_csv('C:\Workspace\Pri\data science and ML practice\jupyter\students.csv',parse_dates=['Date'],index_col='Date')
df
# Out:
#             Stu_ID    Class  Stdy_hrs  Slpng_hrs  present_per_no  \
# Date
# 2016-06-11     1.0   Health         2          9             1.0
# 2016-07-11     2.0   Health         6          8             2.0
# 2016-08-11     NaN   Health         3          8             3.0
# 2016-09-11     NaN    Sport         0         10             NaN
# 2016-10-11     5.0    Sport         4          7             NaN
# 2016-11-11     6.0    Sport        10          7             6.0
# NaN            7.0      NaN         6          7             5.0
# NaN            8.0    Dance         6          8             NaN
# NaN            9.0  Singing         8          9             4.0
# 2016-15-11    10.0  Singing         6          9            10.0
#
#             Mob.Games_hrs Perctg  dumy
# Date
# 2016-06-11            5.0     50   yes
# 2016-07-11            0.0     80   yes
# 2016-08-11            4.0     60    no
# 2016-09-11            5.0     45    no
# ...

# %%
df4 = pd.read_csv('C:\Workspace\Pri\data science and ML practice\jupyter\student_results _small.csv' )
df4
# Out:
#      ID  Class  S_hrs  Sl_hrs  oln_hrs  Gmes_hrs  Perctg
# 0  1001   10.0      2       9        3       5.0      50
# 1  1002    NaN      6       8        2       NaN      80
# 2  1003    NaN      3       8        2       4.0      60
# 3  1004   11.0      0      10        1       5.0      45

# %%
#df4.interpolate( method= 'nearest')        # ImportError: Missing optional dependency 'scipy'. nearest interpolation requires 
#SciPy. Use pip or conda to install scipy.

# %%
df.dtypes
# Out:
# Stu_ID            float64
# Class              object
# Stdy_hrs            int64
# Slpng_hrs           int64
# present_per_no    float64
# Mob.Games_hrs     float64
# Perctg             object
# dumy               object
# dtype: object

# %%
df1.dtypes
# Out:
# Date               object
# Stu_ID            float64
# Class              object
# Stdy_hrs            int64
# Slpng_hrs           int64
# present_per_no    float64
# Mob.Games_hrs     float64
# Perctg             object
# dumy               object
# dtype: object
